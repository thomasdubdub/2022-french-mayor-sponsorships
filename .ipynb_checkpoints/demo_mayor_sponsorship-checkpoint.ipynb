# %% [markdown]
# # Visualize sponsorships of mayors in metropolitan France for next presidential election (2022)

# %%
# %load_ext lab_black

# %%
from collections import defaultdict
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

# %% [markdown]
# #### Load sponsorship data from French open data portal here:
# #### https://www.data.gouv.fr/fr/datasets/parrainages-des-candidats-a-lelection-presidentielle-francaise-de-2022/

# %%
parrainages_url = "https://www.data.gouv.fr/fr/datasets/r/307dbc5d-0907-47e9-a3dc-2836cc906b1c"  # 15/02/22

# %%
p_df = pd.read_csv(parrainages_url, sep=";")
p_df.head(2)
# Out:
#   Civilité       Nom  Prénom Mandat  Circonscription Département  \
# 0       M.  CORDIVAL  Gilles  Maire  Mont-Saint-Père       Aisne
# 1      Mme   VALLIET   Odile  Maire         Crupilly       Aisne
#
#            Candidat Date de publication
# 0  ARTHAUD Nathalie          01/02/2022
# 1  ARTHAUD Nathalie          01/02/2022

# %%
print(f"Nb of sponsorships: {p_df.shape[0]}")
# Out:
# Nb of sponsorships: 8076

# %% [markdown]
# #### Top sponsorships (global)

# %%
p_df["Candidat"].value_counts().nlargest(10)
# Out:
# PÉCRESSE Valérie         1824
# MACRON Emmanuel          1260
# HIDALGO Anne             1007
# ARTHAUD Nathalie          509
# ROUSSEL Fabien            492
# LASSALLE Jean             471
# JADOT Yannick             450
# DUPONT-AIGNAN Nicolas     360
# MÉLENCHON Jean-Luc        332
# LE PEN Marine             331
# Name: Candidat, dtype: int64

# %% [markdown]
# #### Top sponsorships (mayors)

# %%
m_df = p_df.query('Mandat == "Maire"')
print(f"Nb of sponsorships by mayors: {m_df.shape[0]}")
# Out:
# Nb of sponsorships by mayors: 5095

# %%
m_df["Candidat"].value_counts().nlargest(10)
# Out:
# PÉCRESSE Valérie         919
# MACRON Emmanuel          725
# HIDALGO Anne             476
# ARTHAUD Nathalie         467
# LASSALLE Jean            451
# DUPONT-AIGNAN Nicolas    348
# ROUSSEL Fabien           306
# MÉLENCHON Jean-Luc       254
# ZEMMOUR Éric             219
# ASSELINEAU François      168
# Name: Candidat, dtype: int64

# %%
threshold = 25  # candidates with at leat that number of sponsors
above_threshold = list(
    m_df["Candidat"].value_counts()[m_df["Candidat"].value_counts() > threshold].index
)
print(f"{len(above_threshold)} candidates with more than 10 (mayor) sponsorships")
# Out:
# 18 candidates with more than 10 (mayor) sponsorships

# %%
m_f_df = m_df.query("Candidat in @above_threshold")
m_f_df.shape
# Out:
# (5026, 8)

# %% [markdown]
# #### Load info on department from the French open data portal here:
# #### https://www.data.gouv.fr/fr/datasets/departements-de-france/

# %%
dep_url = "https://www.data.gouv.fr/fr/datasets/r/70cef74f-70b1-495a-8500-c089229c0254"

# %%
dep_df = pd.read_csv(dep_url, sep=",")
nom_to_code = dict(zip(dep_df.nom_departement, dep_df.code_departement))
print(len(nom_to_code))
# Out:
# 101

# %% [markdown]
# #### Load city data from OSM open data here:
# #### https://www.data.gouv.fr/fr/datasets/decoupage-administratif-communal-francais-issu-d-openstreetmap/

# %%
osm_fp = "communes-20220101-shp/communes-20220101.shp"

# %%
com_gdf = gpd.read_file(osm_fp)
com_gdf.head(2)
# Out:
#    insee           nom        wikipedia  surf_ha  \
# 0  2B222  Pie-d'Orezza  fr:Pie-d'Orezza    573.0
# 1  2B137          Lano          fr:Lano    824.0
#
#                                             geometry
# 0  POLYGON ((9.32017 42.38507, 9.32028 42.38510, ...
# 1  POLYGON ((9.20010 42.39013, 9.20014 42.39014, ...

# %%
#### Metropolitan France
outre_deps = ["971", "972", "973", "974", "976"]
metro_com_gdf = com_gdf.query("insee.str.slice(0,3) not in @outre_deps")

# %%
m_f_df.query("Circonscription == 'La Foa'")
# Out:
#      Civilité       Nom   Prénom Mandat Circonscription         Département  \
# 7144       M.  METZDORF  Nicolas  Maire          La Foa  Nouvelle-Calédonie
#
#              Candidat Date de publication
# 7144  MACRON Emmanuel          15/02/2022

# %%
metro_com_gdf.query('nom == "Chalette-sur-Loing"')
# Out:
#        insee                 nom              wikipedia  surf_ha  \
# 32569  45068  Chalette-sur-Loing  fr:Chalette-sur-Loing   1311.0
#
#                                                 geometry
# 32569  POLYGON ((2.70143 48.01753, 2.70144 48.01766, ...

# %% [markdown]
# #### Patch difference of names in files

# %%
# Problems of names
[
    l
    for l in list(m_f_df["Circonscription"].unique())
    if l not in list(com_gdf["nom"].unique())
]
# Out:
# ['Les Hauts-Talican',
#  'Le Haut Soultzbach',
#  'Montgaillard en Albret',
#  'Parves et Nattages',
#  'Taiarapu-Est',
#  'Mahina',
#  'La Foa',
#  "Les Monts d'Andaine",
#  'Clichy',
#  'Châlette-sur-Loing']

# %%
# Patch for metropolitan cities (difference in name)
mfp_df = m_f_df.copy()
mfp_df.loc[
    mfp_df.Circonscription == "Les Hauts-Talican", "Circonscription"
] = "Les Hauts Talican"
mfp_df.loc[
    mfp_df.Circonscription == "Le Haut Soultzbach", "Circonscription"
] = "Le Haut-Soultzbach"
mfp_df.loc[
    mfp_df.Circonscription == "Montgaillard en Albret", "Circonscription"
] = "Montgaillard-en-Albret"
mfp_df.loc[
    mfp_df.Circonscription == "Parves et Nattages", "Circonscription"
] = "Parves-et-Nattages"
mfp_df.loc[
    mfp_df.Circonscription == "Les Monts d'Andaine", "Circonscription"
] = "Les Monts-d'Andaine"
mfp_df.loc[mfp_df.Circonscription == "Clichy", "Circonscription"] = "Clichy-la-Garenne"
mfp_df.loc[
    mfp_df.Circonscription == "Châlette-sur-Loing", "Circonscription"
] = "Chalette-sur-Loing"

# %% [markdown]
# #### Get sponsor from code of department and name of city (several French cities have the same name...) - only metropolitan France

# %%
code_city_sponsor = defaultdict(lambda: defaultdict(str))
for index, row in mfp_df.iterrows():
    if row["Département"] in nom_to_code.keys():
        code = nom_to_code[row["Département"]]
        code_city_sponsor[code][row["Circonscription"]] = row["Candidat"]
# test
code_city_sponsor["31"]["Antignac"]
# Out:
# 'LASSALLE Jean'

# %%
gdf = metro_com_gdf.copy()
gdf["candidat"] = gdf.apply(
    lambda x: code_city_sponsor[str(x.insee)[:2]][x.nom], axis=1
)

# %% [markdown]
# #### Plot cities with color of selected candidate (by mayor)

# %%
print(len(above_threshold))
print(above_threshold)
# Out:
# 18
# ['PÉCRESSE Valérie', 'MACRON Emmanuel', 'HIDALGO Anne', 'ARTHAUD Nathalie', 'LASSALLE Jean', 'DUPONT-AIGNAN Nicolas', 'ROUSSEL Fabien', 'MÉLENCHON Jean-Luc', 'ZEMMOUR Éric', 'ASSELINEAU François', 'JADOT Yannick', 'POUTOU Philippe', 'KAZIB Anasse', 'LE PEN Marine', 'THOUY Hélène', 'TAUBIRA Christiane', 'KUZMANOVIC Georges', 'KOENIG Gaspard']

# %%
candidats = {
    "MACRON Emmanuel": "darkorange",
    "PÉCRESSE Valérie": "blue",
    "ARTHAUD Nathalie": "firebrick",
    "LASSALLE Jean": "gold",
    "HIDALGO Anne": "fuchsia",
    "DUPONT-AIGNAN Nicolas": "cyan",
    "ROUSSEL Fabien": "red",
    "MÉLENCHON Jean-Luc": "darkviolet",
    "ZEMMOUR Éric": "black",
    "ASSELINEAU François": "darkcyan",
    "POUTOU Philippe": "crimson",
    "JADOT Yannick": "green",
    "KAZIB Anasse": "indianred",
    "THOUY Hélène": "olive",
    "LE PEN Marine": "darkblue",
    "KUZMANOVIC Georges": "plum",
    "KOENIG Gaspard": "bisque",
    "TAUBIRA Christiane": "violet",
}

# %%
f, ax = plt.subplots(figsize=(18, 18))
pmarks = []
gdf.query("candidat == ''").plot(
    ax=ax,
    color="white",
    edgecolor="gray",
    linewidth=0.07,
)
for candidate, color in candidats.items():
    gdf.query("candidat == @candidate").plot(
        ax=ax,
        color=color,
        categorical=True,
        legend=True,
        edgecolor="gray",
        linewidth=0.07,
    )
    pmarks.append(Patch(facecolor=color, label=candidate))

handles, _ = ax.get_legend_handles_labels()
ax.legend(handles=[*handles, *pmarks], loc="best", fontsize=9)
ax.set_title("France 2022 : parrainage des maires", fontsize=25)
ax.set_axis_off()
plt.savefig("france-sponsors.png", dpi=50, bbox_inches="tight")
